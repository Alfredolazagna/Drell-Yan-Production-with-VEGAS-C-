# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
#Preparation
Qe = -1
Ve = -1/2 + 2*(0.222246)
Ae = -0.50
Vm = -1/2 + 2*(0.222246)
Am = -0.50
alpha = 1/132.507
GF = 1.16639e-5
MZ = 91.188
GammaZ = 2.4414

XMIN = 0.0
YMIN = 0.0
XMAX = 5.0
YMAX = 5.0

def s_to_E(s):
    return np.sqrt(s)
# Function to calculate chi1(s)
def chi1(s):
    kappa = np.sqrt(2) * GF * MZ**2 / (4 * np.pi * alpha)
    return kappa * s * (s - MZ**2) / ((s - MZ**2)**2 + GammaZ**2 * MZ**2)

# Function to calculate chi2(s)
def chi2(s):
    kappa = np.sqrt(2) * GF * MZ**2 / (4 * np.pi * alpha)
    return kappa**2 * s**2 / ((s - MZ**2)**2 + GammaZ**2 * MZ**2)

# Coefficients A0(s) and A1(s)
def A0(s):
    return Qe**2 - 2 * Qe * Ve * Vm * chi1(s) + (Am**2 + Vm**2) * (Ae**2 + Ve**2) * chi2(s)

def A1(s):
    return -4 * Qe * Am * Ae * chi1(s) + 8 * Am * Vm * Ae * Ve * chi2(s)

# Differential cross section function
def diff_cross_section(s, cos_theta):
    return alpha**2 / (4 * s) * (A0(s) * (1 + cos_theta**2) + A1(s) * cos_theta)

# %%
def lego_plot(xAmplitudes, yAmplitudes, nBins, xLabel, yLabel, title):
    x = np.array(xAmplitudes)  # turn x,y data into numpy arrays
    y = np.array(yAmplitudes)  # useful for regular matplotlib arrays

    fig = plt.figure()  # create a canvas, tell matplotlib it's 3d
    ax = fig.add_subplot(111, projection="3d")

    # make histograms - set bins
    hist, xedges, yedges = np.histogram2d(x, y, bins=(nBins, nBins))
    xpos, ypos = np.meshgrid(xedges[:-1] + xedges[1:], yedges[:-1] + yedges[1:])

    xpos = xpos.flatten() / 2.0
    ypos = ypos.flatten() / 2.0
    zpos = np.zeros_like(xpos)

    dx = xedges[1] - xedges[0]
    dy = yedges[1] - yedges[0]
    dz = hist.flatten()

    cmap = mpl.colormaps["jet"]
    max_height = np.max(dz)  # get range of colorbars so we can normalize
    min_height = np.min(dz)
    # scale each z to [0,1], and get their rgb values
    rgba = [cmap((k - min_height) / max_height) for k in dz]

    ax.bar3d(xpos, ypos, zpos, dx, dy, dz, color=rgba, zsort="average")
    plt.title(title)
    plt.xlabel(xLabel)
    plt.ylabel(yLabel)   
    plt.show()

def plot_histograms(s_values, theta_values, nBins):
    # Plot histogram for S
    plt.figure(figsize=(10, 4))
    plt.hist(s_values, bins=nBins, color='skyblue', edgecolor='black')
    plt.title('Histogram of S Values')
    plt.xlabel('S')
    plt.ylabel('Frequency')
    plt.show()

    # Plot histogram for E
    plt.figure(figsize=(10, 4))
    plt.hist(s_to_E(s_values), bins=nBins, color='lightcoral', edgecolor='black')
    plt.title('Histogram of E Values')
    plt.xlabel('E')
    plt.ylabel('Frequency')
    plt.show()

    # Plot histogram for theta
    plt.figure(figsize=(10, 4))
    plt.hist(theta_values, bins=nBins, color='lightgreen', edgecolor='black')
    plt.title('Histogram of Cosine(Theta) Values')
    plt.xlabel('Cos(Theta)')
    plt.ylabel('Frequency')
    plt.show()

    # Plot histogram for cos(theta)
    plt.figure(figsize=(10, 4))
    plt.hist(np.arccos(theta_values), bins=nBins, color='salmon', edgecolor='black')
    plt.title('Histogram of Theta Values')
    plt.xlabel('Theta')
    plt.ylabel('Frequency')
    plt.show()

# %%
s_min, s_max = 10**2, 200**2
COSTHETAMIN, COSTHETAMAX = -1, 1

# # Sampling differential cross-section over the domain to find the maximum value
# sampled_values = []
# for _ in range(100000):
#     random_s = np.random.uniform(s_min, s_max)
#     random_cos_theta = np.random.uniform(cos_theta_min, cos_theta_max)
#     value = diff_cross_section(random_s, random_cos_theta)
#     sampled_values.append(value)

# F_VAL_MAX = max(sampled_values)
F_VAL_MAX = 6.78765661236851e-07
            
#Part a
def brute_force(nPoints, seed=None):
    nFunctionEval = 0
    s_rej_method = []
    cos_theta_rej_method = []
    maxWeightEncounteredRej = -1.0e20
    generator = np.random.RandomState(seed=seed)
    
    while len(s_rej_method) < nPoints:
        rr = generator.uniform(size=3)
        random_s = np.random.uniform(s_min, s_max)
        random_cos_theta = np.random.uniform(COSTHETAMIN, COSTHETAMAX)
        random_value = np.random.uniform(0, F_VAL_MAX)
        nFunctionEval += 1
        f_val = diff_cross_section(random_s, random_cos_theta)
        if f_val > maxWeightEncounteredRej:
            maxWeightEncounteredRej = f_val
        if f_val > F_VAL_MAX:
            print(
                f" f_val={f_val} exceeds F_VAL_MAX={F_VAL_MAX}, program will now exit"
            )
            exit(99)
        if f_val / F_VAL_MAX > rr[2]:
            s_rej_method.append(random_s)
            cos_theta_rej_method.append(random_cos_theta)
    return (s_rej_method, cos_theta_rej_method, nFunctionEval, maxWeightEncounteredRej)

s_rej_method, cos_theta_rej_method, nFunctionEval_rej, maxWeightEncounteredReJ = brute_force(10000)
print(nFunctionEval_rej)
# Out:
# 662891

# %%
lego_plot(np.sqrt(s_rej_method), cos_theta_rej_method, 100, "E", "Cos", "Standard Method")
plot_histograms(s_rej_method, cos_theta_rej_method, 100)

# %%
  #part b
"""def setup_intervals_ours(NN=100, KK=2000, nIterations=4000, alpha_damp=1.5, seed=None):
    # Define the domain boundaries
    SMIN, SMAX = 10**2, 200**2
    COSTHETAMIN, COSTHETAMAX = -1, 1  

   # Initialize intervals with uniform spacing
    sLow = np.linspace(SMIN, SMAX, NN + 1)
    cosLow = np.linspace(COSTHETAMIN, COSTHETAMAX, NN + 1)

   # Initialize weights for intervals (uniform at start)
    weights_s = np.ones(NN)
    weights_cos = np.ones(NN)

     # Random number generator
    rng = np.random.RandomState(seed)
    delx =  np.ones(NN) * (s_max - s_min) / NN
    dely = np.ones(NN) * (COSTHETAMAX - COSTHETAMIN) / NN
     # Iteratively adjust intervals based on function evaluations
    for _ in range(nIterations):
        # Randomly choose intervals based on current weights
        chosen_intervals_s = rng.choice(NN, size=KK, p=weights_s / weights_s.sum())
        chosen_intervals_cos = rng.choice(NN, size=KK, p=weights_cos / weights_cos.sum())

        # Sample within chosen intervals and evaluate the function
        samples_s = sLow[chosen_intervals_s] + rng.rand(KK) * delx[chosen_intervals_s]
        samples_cos = cosLow[chosen_intervals_cos] + rng.rand(KK) * dely[chosen_intervals_cos]
        f_vals = diff_cross_section(samples_s, samples_cos)  # Your differential cross-section function

         # Adjust weights based on function evaluations and damping
        for i in range(NN):
            interval_mask_s = chosen_intervals_s == i
            interval_mask_cos = chosen_intervals_cos == i
            weights_s[i] *= alpha_damp + (f_vals[interval_mask_s].sum() / KK)
            weights_cos[i] *= alpha_damp + (f_vals[interval_mask_cos].sum() / KK)

         # Normalize weights to maintain the same total interval size
        weights_s /= weights_s.sum() / NN
        weights_cos /= weights_cos.sum() / NN

         # Recalculate interval boundaries based on new weights
        sLow[1:-1] = np.cumsum(weights_s[:-1]) * (SMAX - SMIN) / NN + SMIN
        cosLow[1:-1] = np.cumsum(weights_cos[:-1]) * (COSTHETAMAX - COSTHETAMIN) / NN + COSTHETAMIN
        
        delx = np.diff(sLow)
        dely = np.diff(cosLow)

    return sLow, cosLow, delx, dely"""

# %%
def setup_intervals_lab(NN=100, KK=2000, nIterations=4000, alpha_damp=1.5, seed=None):
    """
    Input:
        NN: Number of intervals in [XMIN, XMAX] or [YMIN, YMAX]
        KK: function evaluations per iteration
        nIterations: number of iterations
        alpha_damp: damping parameter in the Vegas algorithm
    Return:
        Intervals specified by xLow, yLow: each is a 1D numpy array of size NN+1, with
        xLow[0] = 0, xLow[NN] = ym; yLow[0] = 0, yLow[NN] = ym
    """

    # intitial intervals: uniform intervals between XMIN/YMIN and XMAX/YMAX
    #sLow = SMIN + (SMAX - SMIN) / NN * np.arange(NN + 1)
    sLow = np.linspace(s_min, s_max, NN + 1)
    del_x = np.ones(NN) * (s_max - s_min) / NN
    p_s = np.ones(NN) / (s_max - s_min)  # probability density in each interval

    costhetaLow = np.linspace(COSTHETAMIN, COSTHETAMAX, NN + 1)
    del_costheta = np.ones(NN) * (COSTHETAMIN - COSTHETAMAX) / NN
    p_costheta = np.ones(NN) / (COSTHETAMAX - COSTHETAMIN)
    
    generator = np.random.RandomState(seed=seed)
    for _ in range(nIterations):
        ixLow = generator.randint(0, NN, size=KK)
        xx = sLow[ixLow] + del_x[ixLow] * generator.uniform(size=KK)
        iyLow = generator.randint(0, NN, size=KK)
        yy = costhetaLow[iyLow] + del_costheta[iyLow] * generator.uniform(size=KK)
        ff = diff_cross_section(xx, yy)
        f2barx = np.array(
            [sum((ff[ixLow == i] / p_costheta[iyLow[ixLow == i]]) ** 2) for i in range(NN)]
        )
        fbarx = np.sqrt(f2barx)
        f2bary = np.array(
            [sum((ff[iyLow == i] / p_s[ixLow[iyLow == i]]) ** 2) for i in range(NN)]
        )
        fbary = np.sqrt(f2bary)
        fbardelxSum = np.sum(fbarx * del_x)
        fbardelySum = np.sum(fbary * del_costheta)
        logArgx = fbarx * del_x / fbardelxSum
        logArgy = fbary * del_costheta / fbardelySum
        mmx = KK * pow((logArgx - 1) / np.log(logArgx), alpha_damp)
        mmx = mmx.astype(int)
        mmx = np.where(mmx > 1, mmx, 1)
        mmy = KK * pow((logArgy - 1) / np.log(logArgy), alpha_damp)
        mmy = mmy.astype(int)
        mmy = np.where(mmy > 1, mmy, 1)
        xLowNew = [sLow[i] + np.arange(mmx[i]) * del_x[i] / mmx[i] for i in range(NN)]
        xLowNew = np.concatenate(xLowNew, axis=0)
        yLowNew = [costhetaLow[i] + np.arange(mmy[i]) * del_costheta[i] / mmy[i] for i in range(NN)]
        yLowNew = np.concatenate(yLowNew, axis=0)
        nCombx = int(len(xLowNew) / NN)
        nComby = int(len(yLowNew) / NN)
        i = np.arange(NN)
        sLow[:-1] = xLowNew[i * nCombx]
        costhetaLow[:-1] = yLowNew[i * nComby]
        del_x = np.diff(sLow)
        del_costheta = np.diff(costhetaLow)
        p_costheta = 1.0 / del_x / NN
        p_s = 1.0 / del_costheta / NN

    return sLow, costhetaLow, del_x, del_costheta

# %%
"""def vegas_ours(nPoints, vegasRatioFactor, NN, KK, nIterations, alpha_damp, seed=None):
    # Setup initial intervals using the setup_intervals function
    COSTHETAMIN, COSTHETAMAX = -1, 1  
    
    sLow, cosLow, delx, dely = setup_intervals_ours(NN, KK, nIterations, alpha_damp, seed)
    vegasRatioMax = vegasRatioFactor * F_VAL_MAX * NN * NN * delx[NN - 2] * dely[NN - 2]

    # Initialize variables
    nFunctionEval = 0
    s = []
    cos = []
    maxWeightEncountered = -1.0e20

    # Random number generator
    rng = np.random.RandomState(seed)

    # Main loop for sampling and evaluating
    while len(s) < nPoints:
        # Sample points within the refined intervals
        ixLow = rng.randint(0, NN)
        iyLow = rng.randint(0, NN)
        ss = sLow[ixLow] + delx[ixLow] * rng.uniform()
        cosT = cosLow[iyLow] + dely[iyLow] * rng.uniform()

        # Evaluate the differential cross-section at the sampled points
        f_vals = diff_cross_section(ss, cosT)
        ratio = f_vals * NN * NN * delx[ixLow] * dely[iyLow]
        nFunctionEval +=1

        # Update the maximum weight encountered, if necessary
        max_f_val = np.max(f_vals)
        if max_f_val > maxWeightEncountered:
            maxWeightEncountered = max_f_val

        # Store points based on the acceptance criterion
        # Accept the point if the Vegas ratio exceeds the vegasRatioFactor threshold
        if ratio > vegasRatioMax:
            print(f"ratio={ratio} exceeds vegasRatioMax={vegasRatioMax}, yy={cosT} program will now exit ")
        if ratio / vegasRatioMax > rng.uniform():
            s.append(ss)
            cos.append(cosT)

    # Prepare the output
    output = (
        s,
        cos,
        nFunctionEval,
        maxWeightEncountered,
        vegasRatioFactor * max_f_val,  # Maximum Vegas ratio considered for acceptance
    )
    
    return output
"""

# %%
def vegas_lab(
    nPoints,
    vegasRatioFactor,
    NN=100,
    KK=2000,
    nIterations=4000,
    alpha_damp=1.5,
    seed=None,
):
    xLow, yLow, delx, dely = setup_intervals_lab(NN, KK, nIterations, alpha_damp, seed)
    vegasRatioMax = vegasRatioFactor * F_VAL_MAX * NN * NN * delx[NN - 2] * dely[NN - 2]
    nFunctionEval = 0
    yy1_vegas_method = []
    yy2_vegas_method = []
    yy1_vrho_method = []
    yy2_vrho_method = []
    maxWeightEncountered = -1.0e20
    
    generator = np.random.RandomState(seed=seed)
    while len(yy1_vegas_method) < nPoints:
        ixLow = generator.randint(0, NN)
        xx = xLow[ixLow] + delx[ixLow] * generator.uniform()
        iyLow = generator.randint(0, NN)
        yy = yLow[iyLow] + delx[iyLow] * generator.uniform()
        yy1_vrho_method.append(xx)
        yy2_vrho_method.append(yy)
        nFunctionEval += 1
        f_val = diff_cross_section(xx, yy)
        ratio = f_val * NN * NN * delx[ixLow] * dely[iyLow]
        if ratio > maxWeightEncountered:
            maxWeightEncountered = ratio
        if ratio > vegasRatioMax:
            print(
                f"ratio={ratio} exceeds vegasRatioMax={vegasRatioMax}, yy={yy} program will now exit "
            )
            exit(99)
        if ratio / vegasRatioMax > generator.uniform():
            yy1_vegas_method.append(xx)
            yy2_vegas_method.append(yy)
    return (
        yy1_vegas_method,
        yy2_vegas_method,
        nFunctionEval,
        maxWeightEncountered,
        vegasRatioMax)

# %%
s_vegas, cos_vegas, nFunctionalEval_vegas, maxweightEncounteredvegas, vegasRatioFactor = vegas_lab(10000, 1, 50, 1000, 500, 1.5)
print(nFunctionalEval_vegas)
print(vegasRatioFactor)
print(maxweightEncounteredvegas)
# Out:
# C:\Users\Nedal\AppData\Local\Temp\ipykernel_1144\1442800613.py:45: RuntimeWarning: invalid value encountered in log
#   mmy = KK * pow((logArgy - 1) / np.log(logArgy), alpha_damp)
# C:\Users\Nedal\AppData\Local\Temp\ipykernel_1144\1442800613.py:46: RuntimeWarning: invalid value encountered in cast
#   mmy = mmy.astype(int)
# ratio=3870.9296312914776 exceeds vegasRatioMax=0.2241491617964645, yy=3261.839888288428 program will now exit
# ratio=1446.8881836424944 exceeds vegasRatioMax=0.2241491617964645, yy=1668.1898161714212 program will now exit
# ratio=0.4725881436538731 exceeds vegasRatioMax=0.2241491617964645, yy=35.52473162391179 program will now exit
# ratio=0.5586056341824714 exceeds vegasRatioMax=0.2241491617964645, yy=43.737650520139894 program will now exit
# ratio=0.47509820410257975 exceeds vegasRatioMax=0.2241491617964645, yy=21.14158117680604 program will now exit
# ratio=0.2527392350324008 exceeds vegasRatioMax=0.2241491617964645, yy=21.29361872995957 program will now exit
# ratio=14.680420943697305 exceeds vegasRatioMax=0.2241491617964645, yy=184.2821601023838 program will now exit
# ratio=0.40357271060904026 exceeds vegasRatioMax=0.2241491617964645, yy=22.23058402914542 program will now exit
# ratio=0.2807828853270672 exceeds vegasRatioMax=0.2241491617964645, yy=14.644464899828328 program will now exit
# ratio=1108.0810234977362 exceeds vegasRatioMax=0.2241491617964645, yy=1655.9491825764503 program will now exit
# ratio=0.5656072690918376 exceeds vegasRatioMax=0.2241491617964645, yy=43.896182227191126 program will now exit
# ratio=0.5805103750696633 exceeds vegasRatioMax=0.2241491617964645, yy=47.315205159817076 program will now exit
# ratio=1.2961068176950106 exceeds vegasRatioMax=0.2241491617964645, yy=47.80337856346764 program will now exit
# ratio=12.686788218762485 exceeds vegasRatioMax=0.2241491617964645, yy=162.22526643171378 program will now exit
# ratio=1980.376888088698 exceeds vegasRatioMax=0.2241491617964645, yy=2601.007496475426 program will now exit
# ratio=114.7844713977405 exceeds vegasRatioMax=0.2241491617964645, yy=514.3737310290883 program will now exit
# ratio=0.28645571733909636 exceeds vegasRatioMax=0.2241491617964645, yy=17.323849184893007 program will now exit
# ratio=0.6032016762495738 exceeds vegasRatioMax=0.2241491617964645, yy=34.57780944090746 program will now exit
# ratio=2310.850100311682 exceeds vegasRatioMax=0.2241491617964645, yy=2288.6865250215856 program will now exit
# ratio=0.28723646223231863 exceeds vegasRatioMax=0.2241491617964645, yy=34.116270473037126 program will now exit
# ratio=0.2670241421421943 exceeds vegasRatioMax=0.2241491617964645, yy=15.095192725546852 program will now exit
# ratio=26.59045429196225 exceeds vegasRatioMax=0.2241491617964645, yy=239.4366953927892 program will now exit
# ratio=7.295985434100053 exceeds vegasRatioMax=0.2241491617964645, yy=145.7049587716923 program will now exit
# ratio=1.8870269954387349 exceeds vegasRatioMax=0.2241491617964645, yy=66.4912250260497 program will now exit
# ratio=1.1891343769079803 exceeds vegasRatioMax=0.2241491617964645, yy=49.61613005089969 program will now exit
# ratio=0.29424148807264805 exceeds vegasRatioMax=0.2241491617964645, yy=21.42040648963718 program will now exit
# ratio=31.102761145200972 exceeds vegasRatioMax=0.2241491617964645, yy=284.4791843728926 program will now exit
# ratio=0.635747106810505 exceeds vegasRatioMax=0.2241491617964645, yy=29.302212190478084 program will now exit
# ratio=24116.322611678042 exceeds vegasRatioMax=0.2241491617964645, yy=6485.236378855646 program will now exit
# ratio=0.7413757038450227 exceeds vegasRatioMax=0.2241491617964645, yy=32.43331970496895 program will now exit
# ratio=0.24992127505852246 exceeds vegasRatioMax=0.2241491617964645, yy=16.813826365768502 program will now exit
# ratio=39.11127979463589 exceeds vegasRatioMax=0.2241491617964645, yy=226.29478903458167 program will now exit
# ratio=7.59728934694671 exceeds vegasRatioMax=0.2241491617964645, yy=131.40361875808895 program will now exit
# ratio=0.5325104656997093 exceeds vegasRatioMax=0.2241491617964645, yy=23.49683783314591 program will now exit
# ratio=58242.58088527343 exceeds vegasRatioMax=0.2241491617964645, yy=10873.04285310039 program will now exit
# ratio=0.5501196841489172 exceeds vegasRatioMax=0.2241491617964645, yy=32.64665703093 program will now exit
# ratio=3.363861287331902 exceeds vegasRatioMax=0.2241491617964645, yy=96.25779200757505 program will now exit
# ratio=0.5531678594745622 exceeds vegasRatioMax=0.2241491617964645, yy=30.38847999670121 program will now exit
# ratio=275.1574256212648 exceeds vegasRatioMax=0.2241491617964645, yy=790.7238119084761 program will now exit
# ratio=3.958348706668415 exceeds vegasRatioMax=0.2241491617964645, yy=105.07825656685671 program will now exit
# ratio=0.2877362710859951 exceeds vegasRatioMax=0.2241491617964645, yy=15.91641458701491 program will now exit
# ratio=56.94749893908648 exceeds vegasRatioMax=0.2241491617964645, yy=367.8331631475353 program will now exit
# ratio=12.826458760008128 exceeds vegasRatioMax=0.2241491617964645, yy=173.6701074254201 program will now exit
# ratio=67.64716101187202 exceeds vegasRatioMax=0.2241491617964645, yy=296.5419585466647 program will now exit
# ratio=0.3427601854370963 exceeds vegasRatioMax=0.2241491617964645, yy=28.03066134230751 program will now exit
# ratio=0.5055011183164483 exceeds vegasRatioMax=0.2241491617964645, yy=28.87279516875718 program will now exit
# ratio=234.78671686837555 exceeds vegasRatioMax=0.2241491617964645, yy=1036.2396334339264 program will now exit
# ratio=915.7088238113313 exceeds vegasRatioMax=0.2241491617964645, yy=1228.389297148468 program will now exit
# ratio=0.5985175694362685 exceeds vegasRatioMax=0.2241491617964645, yy=40.740219962417605 program will now exit
# ratio=1.3381478358766017 exceeds vegasRatioMax=0.2241491617964645, yy=34.694649483467174 program will now exit
# ratio=209.76912016329922 exceeds vegasRatioMax=0.2241491617964645, yy=669.9121163608238 program will now exit
# ratio=2.7477666516983845 exceeds vegasRatioMax=0.2241491617964645, yy=50.568912878214 program will now exit
# ratio=455.61113039300824 exceeds vegasRatioMax=0.2241491617964645, yy=1616.0574345603366 program will now exit
# ratio=1413.3024451903748 exceeds vegasRatioMax=0.2241491617964645, yy=2871.141931310823 program will now exit
# ratio=8.99171463262321 exceeds vegasRatioMax=0.2241491617964645, yy=136.43806808224284 program will now exit
# ratio=0.53021903833388 exceeds vegasRatioMax=0.2241491617964645, yy=30.730675376994768 program will now exit
# ratio=135.6237068979554 exceeds vegasRatioMax=0.2241491617964645, yy=522.5556293059057 program will now exit
# ratio=0.4355773437529681 exceeds vegasRatioMax=0.2241491617964645, yy=31.01214149977879 program will now exit
# ratio=0.23223109609862166 exceeds vegasRatioMax=0.2241491617964645, yy=19.036557433088397 program will now exit
# ratio=601.0092849473964 exceeds vegasRatioMax=0.2241491617964645, yy=1206.0854462991772 program will now exit
# ratio=0.6135910620762439 exceeds vegasRatioMax=0.2241491617964645, yy=37.89037679046519 program will now exit
# ratio=979.4510409248364 exceeds vegasRatioMax=0.2241491617964645, yy=1556.7094364424315 program will now exit
# ratio=4.603805411497555 exceeds vegasRatioMax=0.2241491617964645, yy=85.20167004599905 program will now exit
# ratio=2.4558862296819455 exceeds vegasRatioMax=0.2241491617964645, yy=54.30270512143721 program will now exit
# ratio=431.4546183860158 exceeds vegasRatioMax=0.2241491617964645, yy=767.8101900109634 program will now exit
# ratio=3.4429918013291165 exceeds vegasRatioMax=0.2241491617964645, yy=62.18028610215452 program will now exit
# ratio=301.1865050893787 exceeds vegasRatioMax=0.2241491617964645, yy=1007.1430151317238 program will now exit
# ratio=59.60923060992082 exceeds vegasRatioMax=0.2241491617964645, yy=305.3597153202462 program will now exit
# ratio=367.70665418084985 exceeds vegasRatioMax=0.2241491617964645, yy=976.3364544482667 program will now exit
# ratio=411.5989191643709 exceeds vegasRatioMax=0.2241491617964645, yy=942.9562077310717 program will now exit
# ratio=61.714704453321296 exceeds vegasRatioMax=0.2241491617964645, yy=410.199752579563 program will now exit
# ratio=22.508056513079055 exceeds vegasRatioMax=0.2241491617964645, yy=196.42661335800528 program will now exit
# ratio=0.26981369043792175 exceeds vegasRatioMax=0.2241491617964645, yy=15.548640432565763 program will now exit
# ratio=32.435485054509805 exceeds vegasRatioMax=0.2241491617964645, yy=308.402690335673 program will now exit
# ratio=1.3096061048884253 exceeds vegasRatioMax=0.2241491617964645, yy=41.91219774437106 program will now exit
# ratio=9.86149769438147 exceeds vegasRatioMax=0.2241491617964645, yy=152.19600723995597 program will now exit
# ratio=5.814552515254256 exceeds vegasRatioMax=0.2241491617964645, yy=111.13992197968793 program will now exit
# ratio=0.30413631657307516 exceeds vegasRatioMax=0.2241491617964645, yy=16.224705700188682 program will now exit
# ratio=14.083269832875583 exceeds vegasRatioMax=0.2241491617964645, yy=179.56476302978575 program will now exit
# ratio=16.225193040668998 exceeds vegasRatioMax=0.2241491617964645, yy=96.41040676821184 program will now exit
# ratio=30.69538232240368 exceeds vegasRatioMax=0.2241491617964645, yy=295.0427060780708 program will now exit
# ratio=5.9071239376573335 exceeds vegasRatioMax=0.2241491617964645, yy=104.71412439795024 program will now exit
# ratio=4.797588552229606 exceeds vegasRatioMax=0.2241491617964645, yy=85.81771825007249 program will now exit
# ratio=9.506951227448635 exceeds vegasRatioMax=0.2241491617964645, yy=109.05028505017069 program will now exit
# ratio=1.1603938056785879 exceeds vegasRatioMax=0.2241491617964645, yy=42.68159137543366 program will now exit
# ratio=0.50064991134049 exceeds vegasRatioMax=0.2241491617964645, yy=28.63270051601249 program will now exit
# ratio=660.0772751452672 exceeds vegasRatioMax=0.2241491617964645, yy=970.4184564593378 program will now exit
# ratio=0.24877637004180037 exceeds vegasRatioMax=0.2241491617964645, yy=17.911551903863977 program will now exit
# ratio=374.8187473880666 exceeds vegasRatioMax=0.2241491617964645, yy=810.1429821170706 program will now exit
# ratio=2033.1013223852344 exceeds vegasRatioMax=0.2241491617964645, yy=1961.6794110647247 program will now exit
# ratio=0.3216249474261902 exceeds vegasRatioMax=0.2241491617964645, yy=24.729644829539158 program will now exit
# ratio=43.48525456176402 exceeds vegasRatioMax=0.2241491617964645, yy=290.86888381274883 program will now exit
# ratio=29.648459447436995 exceeds vegasRatioMax=0.2241491617964645, yy=256.1500054111829 program will now exit
# ratio=3727.5978126804657 exceeds vegasRatioMax=0.2241491617964645, yy=3012.8297709189546 program will now exit
# ratio=15.93830023777784 exceeds vegasRatioMax=0.2241491617964645, yy=200.40093219634392 program will now exit
# ratio=6.518085602528843 exceeds vegasRatioMax=0.2241491617964645, yy=96.45714540215228 program will now exit
# ratio=0.7503975269780386 exceeds vegasRatioMax=0.2241491617964645, yy=35.98547882493322 program will now exit
# ratio=0.31307267477275724 exceeds vegasRatioMax=0.2241491617964645, yy=26.219607874337644 program will now exit
# ratio=34.02432420652653 exceeds vegasRatioMax=0.2241491617964645, yy=406.39271801087204 program will now exit
# ratio=1.3726650821534319 exceeds vegasRatioMax=0.2241491617964645, yy=37.279149426656204 program will now exit
# ratio=12.164884792735167 exceeds vegasRatioMax=0.2241491617964645, yy=199.73912068089948 program will now exit
# ratio=173.4193269700099 exceeds vegasRatioMax=0.2241491617964645, yy=650.3582409282561 program will now exit
# ratio=595.5209671127557 exceeds vegasRatioMax=0.2241491617964645, yy=1365.1962459064323 program will now exit
# ratio=1.2566271245133709 exceeds vegasRatioMax=0.2241491617964645, yy=50.560053518824574 program will now exit
# ratio=0.8249575561156903 exceeds vegasRatioMax=0.2241491617964645, yy=29.045581606041946 program will now exit
# ratio=0.629373552570162 exceeds vegasRatioMax=0.2241491617964645, yy=29.92277239073215 program will now exit
# ratio=1.0444246977169593 exceeds vegasRatioMax=0.2241491617964645, yy=38.62229033991936 program will now exit
# ratio=3.9034713743368994 exceeds vegasRatioMax=0.2241491617964645, yy=69.44810056359516 program will now exit
# ratio=1215.6634864734524 exceeds vegasRatioMax=0.2241491617964645, yy=1643.7834016033428 program will now exit
# ratio=0.6064414086372474 exceeds vegasRatioMax=0.2241491617964645, yy=24.87831033789759 program will now exit
# ratio=16.192844512769263 exceeds vegasRatioMax=0.2241491617964645, yy=182.52709433536452 program will now exit
# ratio=1.0363281374703783 exceeds vegasRatioMax=0.2241491617964645, yy=40.17019390644445 program will now exit
# ratio=0.5915569374295552 exceeds vegasRatioMax=0.2241491617964645, yy=41.72804860157189 program will now exit
# ratio=0.4029717052543956 exceeds vegasRatioMax=0.2241491617964645, yy=30.41815948899361 program will now exit
# ratio=0.5669227059901073 exceeds vegasRatioMax=0.2241491617964645, yy=37.42865300358353 program will now exit
# ratio=0.7555457743016867 exceeds vegasRatioMax=0.2241491617964645, yy=33.26488959023376 program will now exit
# ratio=0.9058806518274641 exceeds vegasRatioMax=0.2241491617964645, yy=33.796403909496796 program will now exit
# ratio=816.9832888242771 exceeds vegasRatioMax=0.2241491617964645, yy=1160.5406517752563 program will now exit
# ratio=0.7011579972457619 exceeds vegasRatioMax=0.2241491617964645, yy=39.87667998442143 program will now exit
# ratio=942.5125257182784 exceeds vegasRatioMax=0.2241491617964645, yy=1279.3149455078735 program will now exit
# ratio=0.5121909183522959 exceeds vegasRatioMax=0.2241491617964645, yy=28.602996584825515 program will now exit
# ratio=1492.3888888323715 exceeds vegasRatioMax=0.2241491617964645, yy=1706.6556260602397 program will now exit
# ratio=1.4679850268727193 exceeds vegasRatioMax=0.2241491617964645, yy=39.73688560345214 program will now exit
# ratio=47.635690576797955 exceeds vegasRatioMax=0.2241491617964645, yy=264.35781844514725 program will now exit
# ratio=27.621669465561208 exceeds vegasRatioMax=0.2241491617964645, yy=247.35516515994092 program will now exit
# ratio=0.25596780327605706 exceeds vegasRatioMax=0.2241491617964645, yy=12.905454736458973 program will now exit
# ratio=41.96225877929156 exceeds vegasRatioMax=0.2241491617964645, yy=342.7643842359292 program will now exit
# ratio=1.7425585417067981 exceeds vegasRatioMax=0.2241491617964645, yy=44.03313798750459 program will now exit
# ratio=408.2190923891855 exceeds vegasRatioMax=0.2241491617964645, yy=1005.4628679032292 program will now exit
# ratio=0.39590985989375405 exceeds vegasRatioMax=0.2241491617964645, yy=24.82672513298082 program will now exit
# ratio=170.1954909443249 exceeds vegasRatioMax=0.2241491617964645, yy=450.074318473133 program will now exit
# ratio=0.31046090970515855 exceeds vegasRatioMax=0.2241491617964645, yy=25.046930275243326 program will now exit
# ratio=1.474983047586046 exceeds vegasRatioMax=0.2241491617964645, yy=41.859299329226815 program will now exit
# ratio=1019.1831265513306 exceeds vegasRatioMax=0.2241491617964645, yy=1280.123201710888 program will now exit
# ratio=8.702051503363794 exceeds vegasRatioMax=0.2241491617964645, yy=127.39612578600774 program will now exit
# ratio=0.33327838954874883 exceeds vegasRatioMax=0.2241491617964645, yy=26.24334701891026 program will now exit
# ratio=1256.724854787677 exceeds vegasRatioMax=0.2241491617964645, yy=1777.0932750758384 program will now exit
# ratio=96.24895925795094 exceeds vegasRatioMax=0.2241491617964645, yy=487.722085829458 program will now exit
# ratio=0.4086526270071929 exceeds vegasRatioMax=0.2241491617964645, yy=26.39195288487708 program will now exit
# ratio=679.5951603461646 exceeds vegasRatioMax=0.2241491617964645, yy=1028.1918568142235 program will now exit
# ratio=0.27181842538313783 exceeds vegasRatioMax=0.2241491617964645, yy=14.336779741757136 program will now exit
# ratio=1369.9522218944164 exceeds vegasRatioMax=0.2241491617964645, yy=1720.078900265117 program will now exit
# ratio=1675.1452437999028 exceeds vegasRatioMax=0.2241491617964645, yy=2035.269375777503 program will now exit
# ratio=30.88356451305902 exceeds vegasRatioMax=0.2241491617964645, yy=270.50225989165557 program will now exit
# ratio=345.9674955452296 exceeds vegasRatioMax=0.2241491617964645, yy=986.3306616548052 program will now exit
# ratio=0.4576388483238496 exceeds vegasRatioMax=0.2241491617964645, yy=31.46106160793754 program will now exit
# ratio=2.0753740143670267 exceeds vegasRatioMax=0.2241491617964645, yy=61.72006195532975 program will now exit
# ratio=0.33493563302277546 exceeds vegasRatioMax=0.2241491617964645, yy=36.72220438003977 program will now exit
# ratio=296.53426502821037 exceeds vegasRatioMax=0.2241491617964645, yy=777.0604299317274 program will now exit
# ratio=2.356910953855596 exceeds vegasRatioMax=0.2241491617964645, yy=45.79805951098338 program will now exit
# ratio=79.52888555458208 exceeds vegasRatioMax=0.2241491617964645, yy=370.09860146948097 program will now exit
# ratio=83592.33021817081 exceeds vegasRatioMax=0.2241491617964645, yy=10744.281372027826 program will now exit
# ratio=0.29553785663876925 exceeds vegasRatioMax=0.2241491617964645, yy=18.459105065311487 program will now exit
# ratio=1660.9112331479382 exceeds vegasRatioMax=0.2241491617964645, yy=2009.9832022051867 program will now exit
# ratio=10.024610105914643 exceeds vegasRatioMax=0.2241491617964645, yy=150.09098181394594 program will now exit
# ratio=5.4420011077182515 exceeds vegasRatioMax=0.2241491617964645, yy=114.27092485114068 program will now exit
# ratio=37.20527412442886 exceeds vegasRatioMax=0.2241491617964645, yy=378.09863911644624 program will now exit
# ratio=0.8697426879633389 exceeds vegasRatioMax=0.2241491617964645, yy=36.26390200759589 program will now exit
# ratio=0.2739657258054881 exceeds vegasRatioMax=0.2241491617964645, yy=30.954566830048048 program will now exit
# ratio=0.24295039165347843 exceeds vegasRatioMax=0.2241491617964645, yy=18.517406616084084 program will now exit
# ratio=57.169011808135394 exceeds vegasRatioMax=0.2241491617964645, yy=517.6560124892421 program will now exit
# ratio=4.720860802863288 exceeds vegasRatioMax=0.2241491617964645, yy=71.98668727430334 program will now exit
# ratio=11.323649821438119 exceeds vegasRatioMax=0.2241491617964645, yy=219.39410763742976 program will now exit
# ratio=0.9127494617065464 exceeds vegasRatioMax=0.2241491617964645, yy=29.328553287037014 program will now exit
# ratio=0.6218067921530739 exceeds vegasRatioMax=0.2241491617964645, yy=24.188127039596065 program will now exit
# ratio=23.48332003070955 exceeds vegasRatioMax=0.2241491617964645, yy=230.45298583942005 program will now exit
# ratio=0.2533327235348352 exceeds vegasRatioMax=0.2241491617964645, yy=19.859896539045884 program will now exit
# ratio=0.3550693431668243 exceeds vegasRatioMax=0.2241491617964645, yy=20.30678960541161 program will now exit
# ratio=0.43198651444222885 exceeds vegasRatioMax=0.2241491617964645, yy=26.509870401410506 program will now exit
# ratio=0.6830365485760708 exceeds vegasRatioMax=0.2241491617964645, yy=38.88901411037392 program will now exit
# ratio=0.9089128488188566 exceeds vegasRatioMax=0.2241491617964645, yy=29.25779354221431 program will now exit
# ratio=0.7590341593910541 exceeds vegasRatioMax=0.2241491617964645, yy=26.067622493051676 program will now exit
# ratio=0.25721403478442506 exceeds vegasRatioMax=0.2241491617964645, yy=35.94065979888793 program will now exit
# ratio=287.2882440492663 exceeds vegasRatioMax=0.2241491617964645, yy=943.4130019741938 program will now exit
# ratio=944.9030398990336 exceeds vegasRatioMax=0.2241491617964645, yy=1539.9097889362752 program will now exit
# ratio=1.1125507625999171 exceeds vegasRatioMax=0.2241491617964645, yy=54.8109288503009 program will now exit
# ratio=5519.828654687239 exceeds vegasRatioMax=0.2241491617964645, yy=2680.084972728671 program will now exit
# ratio=0.44813030864972697 exceeds vegasRatioMax=0.2241491617964645, yy=26.4422283133286 program will now exit
# ratio=0.8311327981328145 exceeds vegasRatioMax=0.2241491617964645, yy=49.43116259481094 program will now exit
# ratio=1.2047757662493856 exceeds vegasRatioMax=0.2241491617964645, yy=50.10261962421304 program will now exit
# ratio=62.440548549524706 exceeds vegasRatioMax=0.2241491617964645, yy=294.11402169350856 program will now exit
# ratio=8.543486777164697 exceeds vegasRatioMax=0.2241491617964645, yy=145.251788254223 program will now exit
# ratio=492.8751659488949 exceeds vegasRatioMax=0.2241491617964645, yy=1027.1743829179193 program will now exit
# ratio=38.62930222818241 exceeds vegasRatioMax=0.2241491617964645, yy=250.85483865546362 program will now exit
# ratio=1.2888373757818097 exceeds vegasRatioMax=0.2241491617964645, yy=50.53048403822323 program will now exit
# ratio=62.84422829678607 exceeds vegasRatioMax=0.2241491617964645, yy=434.16118713885936 program will now exit
# ratio=4.079869754705479 exceeds vegasRatioMax=0.2241491617964645, yy=96.52799960974974 program will now exit
# ratio=5.830852371329581 exceeds vegasRatioMax=0.2241491617964645, yy=98.30218023851856 program will now exit
# ratio=2.7046111376313617 exceeds vegasRatioMax=0.2241491617964645, yy=51.845061475309436 program will now exit
# ratio=10034.636211123869 exceeds vegasRatioMax=0.2241491617964645, yy=4844.762572055796 program will now exit
# ratio=0.28031405852310753 exceeds vegasRatioMax=0.2241491617964645, yy=19.292437221551843 program will now exit
# ratio=141.21695136048163 exceeds vegasRatioMax=0.2241491617964645, yy=468.5274151239773 program will now exit
# ratio=37.891023884616914 exceeds vegasRatioMax=0.2241491617964645, yy=239.54188193440544 program will now exit
# ratio=76.83208837641365 exceeds vegasRatioMax=0.2241491617964645, yy=476.311433565235 program will now exit
# ratio=0.37073952310125474 exceeds vegasRatioMax=0.2241491617964645, yy=30.98637255344138 program will now exit
# ratio=0.6994114251717054 exceeds vegasRatioMax=0.2241491617964645, yy=31.09617509379094 program will now exit
# ratio=0.7400878523224201 exceeds vegasRatioMax=0.2241491617964645, yy=32.52055422102036 program will now exit
# ratio=0.2523048796289788 exceeds vegasRatioMax=0.2241491617964645, yy=23.33545347393301 program will now exit
# ratio=0.28913564702663186 exceeds vegasRatioMax=0.2241491617964645, yy=21.904893876528597 program will now exit
# ratio=982.0857221110757 exceeds vegasRatioMax=0.2241491617964645, yy=1795.8827152039087 program will now exit
# ratio=0.47509625596994387 exceeds vegasRatioMax=0.2241491617964645, yy=28.547696165594495 program will now exit
# ratio=28.42566591681385 exceeds vegasRatioMax=0.2241491617964645, yy=197.67136923404084 program will now exit
# ratio=7.470002066928483 exceeds vegasRatioMax=0.2241491617964645, yy=165.98772690687304 program will now exit
# ratio=144.37968485382558 exceeds vegasRatioMax=0.2241491617964645, yy=449.459705366918 program will now exit
# ratio=1.3374582989863641 exceeds vegasRatioMax=0.2241491617964645, yy=49.1529540396943 program will now exit
# ratio=17.63283768554235 exceeds vegasRatioMax=0.2241491617964645, yy=204.18771699767404 program will now exit
# ratio=408.2284781975217 exceeds vegasRatioMax=0.2241491617964645, yy=810.2473395059633 program will now exit
# ratio=2.378429154344212 exceeds vegasRatioMax=0.2241491617964645, yy=56.8212493947636 program will now exit
# ratio=1198.747197103241 exceeds vegasRatioMax=0.2241491617964645, yy=2032.3713494345373 program will now exit
# ratio=45.2044940761052 exceeds vegasRatioMax=0.2241491617964645, yy=277.63603033159046 program will now exit
# ratio=67.03090362447614 exceeds vegasRatioMax=0.2241491617964645, yy=370.37827229100475 program will now exit
# ratio=0.3706838696297353 exceeds vegasRatioMax=0.2241491617964645, yy=24.557146271451646 program will now exit
# ratio=0.313349496103953 exceeds vegasRatioMax=0.2241491617964645, yy=32.6794532142527 program will now exit
# ratio=365.76225952044933 exceeds vegasRatioMax=0.2241491617964645, yy=740.5239292229716 program will now exit
# ratio=5.4569311571128445 exceeds vegasRatioMax=0.2241491617964645, yy=111.76934196128339 program will now exit
# ratio=297.55869362222325 exceeds vegasRatioMax=0.2241491617964645, yy=990.6653632171742 program will now exit
# ratio=7.701944067272919 exceeds vegasRatioMax=0.2241491617964645, yy=81.3961984836307 program will now exit
# ratio=2.460960382141228 exceeds vegasRatioMax=0.2241491617964645, yy=60.65980544036432 program will now exit
# ratio=2600.583086983827 exceeds vegasRatioMax=0.2241491617964645, yy=1885.5553364581629 program will now exit
# ratio=0.22507462357832206 exceeds vegasRatioMax=0.2241491617964645, yy=18.537887451955907 program will now exit
# ratio=493.78046446345684 exceeds vegasRatioMax=0.2241491617964645, yy=1131.9203755082447 program will now exit
# ratio=1.9165552579944842 exceeds vegasRatioMax=0.2241491617964645, yy=62.16138284986319 program will now exit
# ratio=5.798149247818875 exceeds vegasRatioMax=0.2241491617964645, yy=109.65596603510531 program will now exit
# ratio=1278.3920914571518 exceeds vegasRatioMax=0.2241491617964645, yy=1950.818890995981 program will now exit
# ratio=1062.1230429168643 exceeds vegasRatioMax=0.2241491617964645, yy=1186.9116713130004 program will now exit
# ratio=420.55222467681193 exceeds vegasRatioMax=0.2241491617964645, yy=934.4985663474979 program will now exit
# ratio=9.131970758989382 exceeds vegasRatioMax=0.2241491617964645, yy=136.01266049066322 program will now exit
# ratio=177.01983537648513 exceeds vegasRatioMax=0.2241491617964645, yy=518.1317035654718 program will now exit
# ratio=0.6555946166875036 exceeds vegasRatioMax=0.2241491617964645, yy=27.78039698264741 program will now exit
# ratio=3.2105516862316703 exceeds vegasRatioMax=0.2241491617964645, yy=60.24716582831393 program will now exit
# ratio=0.8686436875851974 exceeds vegasRatioMax=0.2241491617964645, yy=27.586618480761768 program will now exit
# ratio=62.101112328621376 exceeds vegasRatioMax=0.2241491617964645, yy=328.5902394832339 program will now exit
# ratio=1262.7902451645045 exceeds vegasRatioMax=0.2241491617964645, yy=1327.567009354082 program will now exit
# ratio=30.354477363475254 exceeds vegasRatioMax=0.2241491617964645, yy=259.8793525616825 program will now exit
# ratio=1210.9638886637847 exceeds vegasRatioMax=0.2241491617964645, yy=1339.5036802359807 program will now exit
# ratio=7.804246598592718 exceeds vegasRatioMax=0.2241491617964645, yy=148.16030745078564 program will now exit
# ratio=0.42825815627485975 exceeds vegasRatioMax=0.2241491617964645, yy=32.91009653874621 program will now exit
# ratio=0.45657436931495937 exceeds vegasRatioMax=0.2241491617964645, yy=38.24839477685592 program will now exit
# ratio=0.36233520058491286 exceeds vegasRatioMax=0.2241491617964645, yy=23.86809224927374 program will now exit
# ratio=0.8774605222433557 exceeds vegasRatioMax=0.2241491617964645, yy=35.44025845922219 program will now exit
# ratio=0.7948797751370977 exceeds vegasRatioMax=0.2241491617964645, yy=38.096296325539505 program will now exit
# ratio=18096.439144827775 exceeds vegasRatioMax=0.2241491617964645, yy=6679.307025640573 program will now exit
# ratio=24.206808076365764 exceeds vegasRatioMax=0.2241491617964645, yy=245.60168240431858 program will now exit
# ratio=977.2323350075167 exceeds vegasRatioMax=0.2241491617964645, yy=1132.912557622671 program will now exit
# ratio=2.5046406344933416 exceeds vegasRatioMax=0.2241491617964645, yy=73.32570991506596 program will now exit
# ratio=307.77843120641035 exceeds vegasRatioMax=0.2241491617964645, yy=759.0090720109133 program will now exit
# ratio=0.5069783094757025 exceeds vegasRatioMax=0.2241491617964645, yy=26.823508695292823 program will now exit
# ratio=0.22861248359593847 exceeds vegasRatioMax=0.2241491617964645, yy=17.844389717869067 program will now exit
# ratio=26.02574352223836 exceeds vegasRatioMax=0.2241491617964645, yy=258.6464795244202 program will now exit
# ratio=0.501409455570505 exceeds vegasRatioMax=0.2241491617964645, yy=28.980113446700347 program will now exit
# ratio=0.23258434561551775 exceeds vegasRatioMax=0.2241491617964645, yy=17.310540112885157 program will now exit
# ratio=2.4759970023013125 exceeds vegasRatioMax=0.2241491617964645, yy=87.85647146001817 program will now exit
# ratio=11.61999569694919 exceeds vegasRatioMax=0.2241491617964645, yy=162.7237371355084 program will now exit
# ratio=0.49550327203038136 exceeds vegasRatioMax=0.2241491617964645, yy=32.059895264239195 program will now exit
# ratio=1919.5105426268863 exceeds vegasRatioMax=0.2241491617964645, yy=2187.601858093017 program will now exit
# ratio=0.22511057840492663 exceeds vegasRatioMax=0.2241491617964645, yy=15.357517636809842 program will now exit
# ratio=4084.72261982581 exceeds vegasRatioMax=0.2241491617964645, yy=2432.3811531571637 program will now exit
# ratio=6.9161848694927075 exceeds vegasRatioMax=0.2241491617964645, yy=81.03137509141872 program will now exit
# ratio=1.0269528062171405 exceeds vegasRatioMax=0.2241491617964645, yy=41.08980840289725 program will now exit
# ratio=1168.643614825831 exceeds vegasRatioMax=0.2241491617964645, yy=1574.9240261303662 program will now exit
# ratio=1.1672223436518243 exceeds vegasRatioMax=0.2241491617964645, yy=48.708114260942146 program will now exit
# ratio=38.58760533142292 exceeds vegasRatioMax=0.2241491617964645, yy=243.65061169876518 program will now exit
# ratio=360.833429573269 exceeds vegasRatioMax=0.2241491617964645, yy=796.0111310040592 program will now exit
# ratio=24.500816152614664 exceeds vegasRatioMax=0.2241491617964645, yy=235.19328559014937 program will now exit
# ratio=244.02938427659794 exceeds vegasRatioMax=0.2241491617964645, yy=734.2155983735013 program will now exit
# ratio=154.34588812764915 exceeds vegasRatioMax=0.2241491617964645, yy=509.67185345765444 program will now exit
# ratio=1.021268394568113 exceeds vegasRatioMax=0.2241491617964645, yy=31.447595974411165 program will now exit
# ratio=208.62118196238654 exceeds vegasRatioMax=0.2241491617964645, yy=592.2380322094631 program will now exit
# ratio=3.944449517384204 exceeds vegasRatioMax=0.2241491617964645, yy=79.99804848215018 program will now exit
# ratio=2.753104141489559 exceeds vegasRatioMax=0.2241491617964645, yy=67.40027266638849 program will now exit
# ratio=1.1392840561359698 exceeds vegasRatioMax=0.2241491617964645, yy=42.028490538028265 program will now exit
# ratio=0.23855752957384574 exceeds vegasRatioMax=0.2241491617964645, yy=17.184897038575382 program will now exit
# ratio=730.4265644229031 exceeds vegasRatioMax=0.2241491617964645, yy=881.6799268349358 program will now exit
# ratio=887.0863849339854 exceeds vegasRatioMax=0.2241491617964645, yy=1528.0065896580847 program will now exit
# ratio=7.942199265480996 exceeds vegasRatioMax=0.2241491617964645, yy=118.30524511575024 program will now exit
# ratio=20.222683232355603 exceeds vegasRatioMax=0.2241491617964645, yy=186.0683802358259 program will now exit
# ratio=0.27980120228275746 exceeds vegasRatioMax=0.2241491617964645, yy=21.53889272108079 program will now exit
# ratio=1.4550150422054078 exceeds vegasRatioMax=0.2241491617964645, yy=41.940132991750495 program will now exit
# ratio=1.2237965883560522 exceeds vegasRatioMax=0.2241491617964645, yy=33.96016166645349 program will now exit
# ratio=1.2449661095096403 exceeds vegasRatioMax=0.2241491617964645, yy=35.63529076055263 program will now exit
# ratio=1.2114123076675223 exceeds vegasRatioMax=0.2241491617964645, yy=47.72076076642159 program will now exit
# ratio=968.999042223084 exceeds vegasRatioMax=0.2241491617964645, yy=1550.3862073795585 program will now exit
# ratio=61.11861670414148 exceeds vegasRatioMax=0.2241491617964645, yy=264.6505070631991 program will now exit
# ratio=16.445445886921913 exceeds vegasRatioMax=0.2241491617964645, yy=185.7668880943668 program will now exit
# ratio=5.338411270655522 exceeds vegasRatioMax=0.2241491617964645, yy=117.00503716186967 program will now exit
# ratio=12.566931617829253 exceeds vegasRatioMax=0.2241491617964645, yy=181.38400419749425 program will now exit
# ratio=1.1940201920778313 exceeds vegasRatioMax=0.2241491617964645, yy=45.393575972476725 program will now exit
# ratio=1.2500006805867252 exceeds vegasRatioMax=0.2241491617964645, yy=47.61918727510362 program will now exit
# ratio=2.4626933292415614 exceeds vegasRatioMax=0.2241491617964645, yy=54.31379849477627 program will now exit
# ratio=212.1088044332481 exceeds vegasRatioMax=0.2241491617964645, yy=431.33721849448193 program will now exit
# ratio=557.5756780463623 exceeds vegasRatioMax=0.2241491617964645, yy=1112.671594366172 program will now exit
# ratio=5.778922019391729 exceeds vegasRatioMax=0.2241491617964645, yy=82.32098588932841 program will now exit
# ratio=0.4718318737242302 exceeds vegasRatioMax=0.2241491617964645, yy=17.80903176873887 program will now exit
# ratio=0.373709140754499 exceeds vegasRatioMax=0.2241491617964645, yy=18.443156253283888 program will now exit
# ratio=125.23155346989016 exceeds vegasRatioMax=0.2241491617964645, yy=531.1398049962455 program will now exit
# ratio=13.73511056062088 exceeds vegasRatioMax=0.2241491617964645, yy=137.18801659836302 program will now exit
# ratio=6.340881263660767 exceeds vegasRatioMax=0.2241491617964645, yy=168.313381453103 program will now exit
# ratio=41.28658112496364 exceeds vegasRatioMax=0.2241491617964645, yy=248.14668282306783 program will now exit
# ratio=3585.3700876955486 exceeds vegasRatioMax=0.2241491617964645, yy=2669.8224959073887 program will now exit
# ratio=3088.5433433447765 exceeds vegasRatioMax=0.2241491617964645, yy=1771.8041289948005 program will now exit
# ratio=51901.80498543235 exceeds vegasRatioMax=0.2241491617964645, yy=11505.60965020007 program will now exit
# ratio=106.90041439263106 exceeds vegasRatioMax=0.2241491617964645, yy=391.9407991591281 program will now exit
# ratio=3.5566366604660464 exceeds vegasRatioMax=0.2241491617964645, yy=78.80092152069128 program will now exit
# ratio=0.5191024068967177 exceeds vegasRatioMax=0.2241491617964645, yy=27.42207102349759 program will now exit
# ratio=1.3795874994192907 exceeds vegasRatioMax=0.2241491617964645, yy=52.924630622007356 program will now exit
# ratio=198.30967442248766 exceeds vegasRatioMax=0.2241491617964645, yy=607.5052915586326 program will now exit
# ratio=10.099858455271306 exceeds vegasRatioMax=0.2241491617964645, yy=152.70269405237528 program will now exit
# ratio=2.3360457403105954 exceeds vegasRatioMax=0.2241491617964645, yy=54.1632979452159 program will now exit
# ratio=363.30044769785076 exceeds vegasRatioMax=0.2241491617964645, yy=675.2573764955458 program will now exit
# ratio=7161.761908030597 exceeds vegasRatioMax=0.2241491617964645, yy=4227.897387350036 program will now exit
# ratio=0.7626225506920935 exceeds vegasRatioMax=0.2241491617964645, yy=33.74547479076875 program will now exit
# ratio=0.833401785177071 exceeds vegasRatioMax=0.2241491617964645, yy=28.29734629705231 program will now exit
# ratio=5.5869975045795774 exceeds vegasRatioMax=0.2241491617964645, yy=95.81232013527053 program will now exit
# ratio=16.3248393435745 exceeds vegasRatioMax=0.2241491617964645, yy=140.20303076091378 program will now exit
# ratio=5.24727364883227 exceeds vegasRatioMax=0.2241491617964645, yy=114.92985435620722 program will now exit
# ratio=74.67840922148518 exceeds vegasRatioMax=0.2241491617964645, yy=338.34251979983037 program will now exit
# ratio=71.47673548549086 exceeds vegasRatioMax=0.2241491617964645, yy=398.7314812903554 program will now exit
# ratio=93.44335931442208 exceeds vegasRatioMax=0.2241491617964645, yy=456.2918609693269 program will now exit
# ratio=165.88233624745425 exceeds vegasRatioMax=0.2241491617964645, yy=681.167594611475 program will now exit
# ratio=151.4294110022847 exceeds vegasRatioMax=0.2241491617964645, yy=523.300796604584 program will now exit
# ratio=2.0454679755483807 exceeds vegasRatioMax=0.2241491617964645, yy=65.20773384027527 program will now exit
# ratio=0.8618562009535802 exceeds vegasRatioMax=0.2241491617964645, yy=34.910108056527804 program will now exit
# ratio=18.469877332308428 exceeds vegasRatioMax=0.2241491617964645, yy=186.28097597610906 program will now exit
# ratio=7.994013759964182 exceeds vegasRatioMax=0.2241491617964645, yy=71.35102992604847 program will now exit
# ratio=162.60877150054569 exceeds vegasRatioMax=0.2241491617964645, yy=771.53846108756 program will now exit
# ratio=456.0153286845738 exceeds vegasRatioMax=0.2241491617964645, yy=1002.5443448663107 program will now exit
# ratio=0.31308837814681034 exceeds vegasRatioMax=0.2241491617964645, yy=18.821337104501218 program will now exit
# ratio=881.0898235376654 exceeds vegasRatioMax=0.2241491617964645, yy=1179.3170325801311 program will now exit
# ratio=16.902798194958976 exceeds vegasRatioMax=0.2241491617964645, yy=152.06514014374702 program will now exit
# ratio=43.36863294409446 exceeds vegasRatioMax=0.2241491617964645, yy=503.9204805392938 program will now exit
# ratio=0.4024712702801235 exceeds vegasRatioMax=0.2241491617964645, yy=17.718033545165728 program will now exit
# ratio=3.3795300547509757 exceeds vegasRatioMax=0.2241491617964645, yy=88.72141339245165 program will now exit
# ratio=0.25147635384124084 exceeds vegasRatioMax=0.2241491617964645, yy=19.9575883431057 program will now exit
# ratio=0.8827395376875112 exceeds vegasRatioMax=0.2241491617964645, yy=31.564430969727532 program will now exit
# ratio=0.29980604142149336 exceeds vegasRatioMax=0.2241491617964645, yy=21.399668169006368 program will now exit
# ratio=0.6977076758058953 exceeds vegasRatioMax=0.2241491617964645, yy=39.727809180919586 program will now exit
# ratio=16.50450510939134 exceeds vegasRatioMax=0.2241491617964645, yy=163.79523318261954 program will now exit
# ratio=14374.355775402448 exceeds vegasRatioMax=0.2241491617964645, yy=5348.044520372491 program will now exit
# ratio=102.14656810777096 exceeds vegasRatioMax=0.2241491617964645, yy=493.4953016842349 program will now exit
# ratio=0.5623071044473849 exceeds vegasRatioMax=0.2241491617964645, yy=34.86288197171353 program will now exit
# ratio=1.7528094889346353 exceeds vegasRatioMax=0.2241491617964645, yy=62.483683737653394 program will now exit
# ratio=1.4696885313059296 exceeds vegasRatioMax=0.2241491617964645, yy=50.38189417057558 program will now exit
# ratio=40.547161487629694 exceeds vegasRatioMax=0.2241491617964645, yy=307.91260893901057 program will now exit
# ratio=4418.873650964971 exceeds vegasRatioMax=0.2241491617964645, yy=2985.7960951906516 program will now exit
# ratio=47292.99454154632 exceeds vegasRatioMax=0.2241491617964645, yy=9359.760228716947 program will now exit
# ratio=92.66392949081029 exceeds vegasRatioMax=0.2241491617964645, yy=490.6623337773227 program will now exit
# ratio=212.70834694663853 exceeds vegasRatioMax=0.2241491617964645, yy=592.0073328864326 program will now exit
# ratio=0.2299382090425219 exceeds vegasRatioMax=0.2241491617964645, yy=18.30245572804031 program will now exit
# ratio=3983.725855735083 exceeds vegasRatioMax=0.2241491617964645, yy=1904.6869669737741 program will now exit
# ratio=0.4069295815280951 exceeds vegasRatioMax=0.2241491617964645, yy=28.090338538797976 program will now exit
# ratio=157.88240779327737 exceeds vegasRatioMax=0.2241491617964645, yy=528.9430670699753 program will now exit
# ratio=1.8899582124354861 exceeds vegasRatioMax=0.2241491617964645, yy=47.86686000237116 program will now exit
# ratio=262.0649126867809 exceeds vegasRatioMax=0.2241491617964645, yy=628.422488982874 program will now exit
# ratio=0.9847609477403668 exceeds vegasRatioMax=0.2241491617964645, yy=43.148642443492136 program will now exit
# ratio=0.29409646510877285 exceeds vegasRatioMax=0.2241491617964645, yy=25.25592725587514 program will now exit
# ratio=0.22733235323586953 exceeds vegasRatioMax=0.2241491617964645, yy=22.271656683780378 program will now exit
# ratio=2.5961613977220517 exceeds vegasRatioMax=0.2241491617964645, yy=66.70226944551106 program will now exit
# ratio=16.359220799631913 exceeds vegasRatioMax=0.2241491617964645, yy=193.48029673936603 program will now exit
# ratio=21.604265049182576 exceeds vegasRatioMax=0.2241491617964645, yy=166.2261735265409 program will now exit
# ratio=56.429496909033816 exceeds vegasRatioMax=0.2241491617964645, yy=333.245187941399 program will now exit
# ratio=22.20380843072691 exceeds vegasRatioMax=0.2241491617964645, yy=203.33479865453234 program will now exit
# ratio=23.99563777713594 exceeds vegasRatioMax=0.2241491617964645, yy=256.11985603151976 program will now exit
# ratio=0.2797830844916498 exceeds vegasRatioMax=0.2241491617964645, yy=15.811940563058586 program will now exit
# ratio=1.1025595831347952 exceeds vegasRatioMax=0.2241491617964645, yy=40.83841889802579 program will now exit
# ratio=35.408212528063764 exceeds vegasRatioMax=0.2241491617964645, yy=467.5453112553082 program will now exit
# ratio=17.293222373502495 exceeds vegasRatioMax=0.2241491617964645, yy=203.86362641182276 program will now exit
# ratio=0.5756218006856086 exceeds vegasRatioMax=0.2241491617964645, yy=24.581126787112176 program will now exit
# ratio=0.32720971933925835 exceeds vegasRatioMax=0.2241491617964645, yy=26.43788779439299 program will now exit
# ratio=1796.6280821815592 exceeds vegasRatioMax=0.2241491617964645, yy=1797.4500979734546 program will now exit
# ratio=17315.99403785058 exceeds vegasRatioMax=0.2241491617964645, yy=4504.421000162864 program will now exit
# ratio=5.61307943280869 exceeds vegasRatioMax=0.2241491617964645, yy=140.57684101654044 program will now exit
# ratio=1424.7245543836493 exceeds vegasRatioMax=0.2241491617964645, yy=1961.7222289955992 program will now exit
# ratio=7219.604621630569 exceeds vegasRatioMax=0.2241491617964645, yy=3094.4140647624426 program will now exit
# ratio=0.259022713666692 exceeds vegasRatioMax=0.2241491617964645, yy=22.979821302359667 program will now exit
# ratio=3.226085902765418 exceeds vegasRatioMax=0.2241491617964645, yy=74.41326117407894 program will now exit
# ratio=1701.7852958203148 exceeds vegasRatioMax=0.2241491617964645, yy=1731.355829334346 program will now exit
# ratio=766.893789603335 exceeds vegasRatioMax=0.2241491617964645, yy=1826.6636219307684 program will now exit
# ratio=0.2963036922371892 exceeds vegasRatioMax=0.2241491617964645, yy=19.175396528135884 program will now exit
# ratio=606.8988610617438 exceeds vegasRatioMax=0.2241491617964645, yy=880.6290618116559 program will now exit
# ratio=4320.759101489632 exceeds vegasRatioMax=0.2241491617964645, yy=2641.7157604221898 program will now exit
# ratio=0.310436169161406 exceeds vegasRatioMax=0.2241491617964645, yy=19.346266807748684 program will now exit
# ratio=0.7698255732964245 exceeds vegasRatioMax=0.2241491617964645, yy=47.22232003511479 program will now exit
# ratio=0.671155945431449 exceeds vegasRatioMax=0.2241491617964645, yy=37.4120678597077 program will now exit
# ratio=3201.580323314027 exceeds vegasRatioMax=0.2241491617964645, yy=2070.155487151712 program will now exit
# ratio=1.1993960382949915 exceeds vegasRatioMax=0.2241491617964645, yy=51.66306874596121 program will now exit
# ratio=3362.881119156002 exceeds vegasRatioMax=0.2241491617964645, yy=1889.1000592887385 program will now exit
# ratio=13.32090056833732 exceeds vegasRatioMax=0.2241491617964645, yy=180.9518583631238 program will now exit
# ratio=3.141092871034621 exceeds vegasRatioMax=0.2241491617964645, yy=84.04766549605351 program will now exit
# ratio=0.29579822154582924 exceeds vegasRatioMax=0.2241491617964645, yy=21.55994063181065 program will now exit
# ratio=0.2591209497129117 exceeds vegasRatioMax=0.2241491617964645, yy=16.08698125351508 program will now exit
# ratio=0.6695288149884284 exceeds vegasRatioMax=0.2241491617964645, yy=28.567493009572924 program will now exit
# ratio=23.843805524562054 exceeds vegasRatioMax=0.2241491617964645, yy=265.4766187078175 program will now exit
# ratio=1.4731744913591114 exceeds vegasRatioMax=0.2241491617964645, yy=60.97812007361114 program will now exit
# ratio=0.2877052872697238 exceeds vegasRatioMax=0.2241491617964645, yy=18.187205363614638 program will now exit
# ratio=1.7766436032377995 exceeds vegasRatioMax=0.2241491617964645, yy=59.209721631696986 program will now exit
# ratio=0.4650725225864127 exceeds vegasRatioMax=0.2241491617964645, yy=30.247393594849452 program will now exit
# ratio=0.2592790597021111 exceeds vegasRatioMax=0.2241491617964645, yy=16.333286906387965 program will now exit
# ratio=11.790153267030904 exceeds vegasRatioMax=0.2241491617964645, yy=163.45265172071478 program will now exit
# ratio=1.2888543798786616 exceeds vegasRatioMax=0.2241491617964645, yy=50.79571763636392 program will now exit
# ratio=0.41404715538481784 exceeds vegasRatioMax=0.2241491617964645, yy=27.25892661711128 program will now exit
# ratio=2.1470304879634288 exceeds vegasRatioMax=0.2241491617964645, yy=78.37276300362467 program will now exit
# ratio=0.5567921234703149 exceeds vegasRatioMax=0.2241491617964645, yy=32.95237655918928 program will now exit
# ratio=2.463880266182191 exceeds vegasRatioMax=0.2241491617964645, yy=48.80703942468035 program will now exit
# ratio=4798.848356132416 exceeds vegasRatioMax=0.2241491617964645, yy=3859.3344207123373 program will now exit
# ratio=22.310031671689295 exceeds vegasRatioMax=0.2241491617964645, yy=244.24850572597555 program will now exit
# ratio=20.041046178373385 exceeds vegasRatioMax=0.2241491617964645, yy=205.22144828143107 program will now exit
# ratio=1167.316978392397 exceeds vegasRatioMax=0.2241491617964645, yy=1429.7381169703858 program will now exit
# ratio=8.030988486668791 exceeds vegasRatioMax=0.2241491617964645, yy=138.74746861949484 program will now exit
# ratio=264.2253153582937 exceeds vegasRatioMax=0.2241491617964645, yy=901.3020204867471 program will now exit
# ratio=10.833309689393658 exceeds vegasRatioMax=0.2241491617964645, yy=178.8642105527151 program will now exit
# ratio=0.6273146797210979 exceeds vegasRatioMax=0.2241491617964645, yy=36.554842990450865 program will now exit
# ratio=74.22169895173319 exceeds vegasRatioMax=0.2241491617964645, yy=375.283646148246 program will now exit
# ratio=72.05114206236738 exceeds vegasRatioMax=0.2241491617964645, yy=342.80733663029986 program will now exit
# ratio=85.25513120190267 exceeds vegasRatioMax=0.2241491617964645, yy=480.02509794936054 program will now exit
# ratio=0.2602301391398357 exceeds vegasRatioMax=0.2241491617964645, yy=17.216781688994487 program will now exit
# ratio=0.6904424798646038 exceeds vegasRatioMax=0.2241491617964645, yy=31.229592282166905 program will now exit
# ratio=0.5863611006022794 exceeds vegasRatioMax=0.2241491617964645, yy=26.147156659915858 program will now exit
# ratio=0.2613370080492878 exceeds vegasRatioMax=0.2241491617964645, yy=15.513294604294833 program will now exit
# ratio=293.52043475417594 exceeds vegasRatioMax=0.2241491617964645, yy=765.644864114899 program will now exit
# ratio=0.2306537047550322 exceeds vegasRatioMax=0.2241491617964645, yy=19.207655000336974 program will now exit
# ratio=77.91389924037513 exceeds vegasRatioMax=0.2241491617964645, yy=512.5782647695289 program will now exit
# ratio=0.36504736297946705 exceeds vegasRatioMax=0.2241491617964645, yy=15.073969468785382 program will now exit
# ratio=1.679093182495166 exceeds vegasRatioMax=0.2241491617964645, yy=54.242576708639824 program will now exit
# ratio=269.1232780286962 exceeds vegasRatioMax=0.2241491617964645, yy=794.3184664517995 program will now exit
# ratio=0.5090532492854184 exceeds vegasRatioMax=0.2241491617964645, yy=20.54462828937625 program will now exit
# ratio=0.5023343420706985 exceeds vegasRatioMax=0.2241491617964645, yy=47.56508569785133 program will now exit
# ratio=121.11920931342733 exceeds vegasRatioMax=0.2241491617964645, yy=542.6364845474278 program will now exit
# ratio=738.0492731443503 exceeds vegasRatioMax=0.2241491617964645, yy=1426.3584885271312 program will now exit
# ratio=9269.533986207 exceeds vegasRatioMax=0.2241491617964645, yy=5231.804985504065 program will now exit
# ...
# ratio=1.7046202519481295 exceeds vegasRatioMax=0.2241491617964645, yy=58.22161676435749 program will now exit
# ratio=1.7180562501965224 exceeds vegasRatioMax=0.2241491617964645, yy=52.2448521220982 program will now exit
# ratio=0.8914101355245495 exceeds vegasRatioMax=0.2241491617964645, yy=41.393649480411284 program will now exit
# ratio=1.6923893950175368 exceeds vegasRatioMax=0.2241491617964645, yy=48.24059803397007 program will now exit
# ratio=0.33662363225732644 exceeds vegasRatioMax=0.2241491617964645, yy=22.0009041474658 program will now exit
# ratio=2.0214290414129046 exceeds vegasRatioMax=0.2241491617964645, yy=62.984580088789635 program will now exit
# ratio=1251.8812141246963 exceeds vegasRatioMax=0.2241491617964645, yy=1439.1228524535668 program will now exit
# ratio=0.5423628717579535 exceeds vegasRatioMax=0.2241491617964645, yy=39.0322739109018 program will now exit
# ratio=36.233693656412214 exceeds vegasRatioMax=0.2241491617964645, yy=282.3447684599569 program will now exit
# ratio=4.636803308007655 exceeds vegasRatioMax=0.2241491617964645, yy=73.46176188550274 program will now exit
# ratio=5.651755756855334 exceeds vegasRatioMax=0.2241491617964645, yy=104.68681196384613 program will now exit
# ratio=1.1920061730109757 exceeds vegasRatioMax=0.2241491617964645, yy=25.63943194589123 program will now exit
# ratio=0.4975251832983416 exceeds vegasRatioMax=0.2241491617964645, yy=39.04497885697735 program will now exit
# ratio=5.978921886450516 exceeds vegasRatioMax=0.2241491617964645, yy=114.33946754502324 program will now exit
# ratio=1522.0584616415633 exceeds vegasRatioMax=0.2241491617964645, yy=2197.0030731264023 program will now exit
# ratio=0.969129461664684 exceeds vegasRatioMax=0.2241491617964645, yy=42.154481116459884 program will now exit
# ratio=17.8324195521185 exceeds vegasRatioMax=0.2241491617964645, yy=185.6404492619809 program will now exit
# ratio=1.929806765874441 exceeds vegasRatioMax=0.2241491617964645, yy=53.837562920572864 program will now exit
# ratio=55.910379758193535 exceeds vegasRatioMax=0.2241491617964645, yy=385.81465125286655 program will now exit
# ratio=1.0640134312912524 exceeds vegasRatioMax=0.2241491617964645, yy=37.791334788243184 program will now exit
# ratio=1825.560568954087 exceeds vegasRatioMax=0.2241491617964645, yy=1939.3769294199487 program will now exit
# ratio=2245.3443688069556 exceeds vegasRatioMax=0.2241491617964645, yy=1782.598670767743 program will now exit
# ratio=14.632956257284116 exceeds vegasRatioMax=0.2241491617964645, yy=168.37705236207736 program will now exit
# ratio=257.9737191270988 exceeds vegasRatioMax=0.2241491617964645, yy=939.9538877960348 program will now exit
# ratio=2.8224940578821394 exceeds vegasRatioMax=0.2241491617964645, yy=59.6506040056531 program will now exit
# ratio=16.620164004914667 exceeds vegasRatioMax=0.2241491617964645, yy=196.56619089956448 program will now exit
# ratio=122.65705546672199 exceeds vegasRatioMax=0.2241491617964645, yy=570.0893730680523 program will now exit
# ratio=60.68261363219576 exceeds vegasRatioMax=0.2241491617964645, yy=418.22367575000516 program will now exit
# ratio=690.6877019659617 exceeds vegasRatioMax=0.2241491617964645, yy=1087.1625669717394 program will now exit
# ratio=36.70081268207059 exceeds vegasRatioMax=0.2241491617964645, yy=269.30923143559727 program will now exit
# ratio=0.5160985848264995 exceeds vegasRatioMax=0.2241491617964645, yy=30.19367034081572 program will now exit
# ratio=3.1824255119115707 exceeds vegasRatioMax=0.2241491617964645, yy=75.2038273771764 program will now exit
# ratio=21.559512507345417 exceeds vegasRatioMax=0.2241491617964645, yy=194.88381653279978 program will now exit
# ratio=0.5219485542255836 exceeds vegasRatioMax=0.2241491617964645, yy=25.30967851142657 program will now exit
# ratio=0.49903439498642416 exceeds vegasRatioMax=0.2241491617964645, yy=29.229974701843823 program will now exit
# ratio=0.2693536033615971 exceeds vegasRatioMax=0.2241491617964645, yy=19.133269554844283 program will now exit
# ratio=0.41150738045435037 exceeds vegasRatioMax=0.2241491617964645, yy=36.56485372809431 program will now exit
# ratio=4.186148211086808 exceeds vegasRatioMax=0.2241491617964645, yy=102.6031948949894 program will now exit
# ratio=69452.9559534229 exceeds vegasRatioMax=0.2241491617964645, yy=8836.138209371678 program will now exit
# ratio=0.226207601581383 exceeds vegasRatioMax=0.2241491617964645, yy=21.958974676343 program will now exit
# ratio=4.236416551598534 exceeds vegasRatioMax=0.2241491617964645, yy=84.75749650410883 program will now exit
# ratio=1.333373098650024 exceeds vegasRatioMax=0.2241491617964645, yy=54.46496917215491 program will now exit
# ratio=0.7284724170209469 exceeds vegasRatioMax=0.2241491617964645, yy=26.42153628261978 program will now exit
# ratio=0.29875511937937704 exceeds vegasRatioMax=0.2241491617964645, yy=22.642668107428445 program will now exit
# ratio=4676.194258751069 exceeds vegasRatioMax=0.2241491617964645, yy=3224.2732372175983 program will now exit
# ratio=16.713605732042655 exceeds vegasRatioMax=0.2241491617964645, yy=245.91319126346542 program will now exit
# ratio=0.25370715639209895 exceeds vegasRatioMax=0.2241491617964645, yy=18.841348390788674 program will now exit
# ratio=6.225171433344139 exceeds vegasRatioMax=0.2241491617964645, yy=121.51315478824321 program will now exit
# ratio=0.2649415020219654 exceeds vegasRatioMax=0.2241491617964645, yy=31.03560622872419 program will now exit
# ratio=6.679710674798396 exceeds vegasRatioMax=0.2241491617964645, yy=127.66496280870483 program will now exit
# ratio=0.4683076568226728 exceeds vegasRatioMax=0.2241491617964645, yy=27.217657539570673 program will now exit
# ratio=961.8747302786134 exceeds vegasRatioMax=0.2241491617964645, yy=1044.4451017798763 program will now exit
# ratio=614.9505850182303 exceeds vegasRatioMax=0.2241491617964645, yy=1242.1456169643038 program will now exit
# ratio=1.274400708947804 exceeds vegasRatioMax=0.2241491617964645, yy=39.037210421720296 program will now exit
# ratio=43.539786696191065 exceeds vegasRatioMax=0.2241491617964645, yy=284.3438354452324 program will now exit
# ratio=2.501076797582745 exceeds vegasRatioMax=0.2241491617964645, yy=60.48450501167807 program will now exit
# ratio=0.6449878437681166 exceeds vegasRatioMax=0.2241491617964645, yy=36.33779446286209 program will now exit
# ratio=0.40163417264869444 exceeds vegasRatioMax=0.2241491617964645, yy=27.79704216751427 program will now exit
# ratio=1.8370423114102306 exceeds vegasRatioMax=0.2241491617964645, yy=65.14109009306148 program will now exit
# ratio=3.545528285865336 exceeds vegasRatioMax=0.2241491617964645, yy=94.27662138523145 program will now exit
# ratio=8.034889302049603 exceeds vegasRatioMax=0.2241491617964645, yy=122.06927022641588 program will now exit
# ratio=109.22193422237429 exceeds vegasRatioMax=0.2241491617964645, yy=517.3000858421931 program will now exit
# ratio=0.5560556050285829 exceeds vegasRatioMax=0.2241491617964645, yy=35.951044244381734 program will now exit
# ratio=20.917215682407495 exceeds vegasRatioMax=0.2241491617964645, yy=186.14677474628996 program will now exit
# ratio=8.908256598228476 exceeds vegasRatioMax=0.2241491617964645, yy=119.55689950606325 program will now exit
# ratio=7052.520817836955 exceeds vegasRatioMax=0.2241491617964645, yy=3538.402916532174 program will now exit
# ratio=1.250710229795163 exceeds vegasRatioMax=0.2241491617964645, yy=36.884397152102046 program will now exit
# ratio=21.885820257187543 exceeds vegasRatioMax=0.2241491617964645, yy=176.50036802491937 program will now exit
# ratio=0.8475303965745609 exceeds vegasRatioMax=0.2241491617964645, yy=37.04485086004575 program will now exit
# ratio=18.277874228446652 exceeds vegasRatioMax=0.2241491617964645, yy=161.99169058432142 program will now exit
# ratio=0.2495962283375269 exceeds vegasRatioMax=0.2241491617964645, yy=16.843810044330503 program will now exit
# ratio=951.862304981967 exceeds vegasRatioMax=0.2241491617964645, yy=1125.165614878973 program will now exit
# ratio=0.4721163419509472 exceeds vegasRatioMax=0.2241491617964645, yy=30.884203402801138 program will now exit
# ratio=15.768467872550577 exceeds vegasRatioMax=0.2241491617964645, yy=166.34173250243447 program will now exit
# ratio=1011.6895145070566 exceeds vegasRatioMax=0.2241491617964645, yy=1651.7745931578404 program will now exit
# ratio=1.9995739447873255 exceeds vegasRatioMax=0.2241491617964645, yy=54.26924629315715 program will now exit
# ratio=1.5921249670871689 exceeds vegasRatioMax=0.2241491617964645, yy=49.04337126064073 program will now exit
# ratio=3.5984600640917748 exceeds vegasRatioMax=0.2241491617964645, yy=89.3057716024423 program will now exit
# ratio=0.9279026702818135 exceeds vegasRatioMax=0.2241491617964645, yy=47.62648281288445 program will now exit
# ratio=0.2766962813511833 exceeds vegasRatioMax=0.2241491617964645, yy=22.558238625113926 program will now exit
# ratio=6.4765296437780675 exceeds vegasRatioMax=0.2241491617964645, yy=138.3696021441163 program will now exit
# ratio=1.306230416955984 exceeds vegasRatioMax=0.2241491617964645, yy=48.49114601832095 program will now exit
# ratio=10.638362206893206 exceeds vegasRatioMax=0.2241491617964645, yy=151.77628478170502 program will now exit
# ratio=0.40842302180915707 exceeds vegasRatioMax=0.2241491617964645, yy=18.18811632448013 program will now exit
# ratio=0.6042301994068234 exceeds vegasRatioMax=0.2241491617964645, yy=34.622475367627445 program will now exit
# ratio=5.387724351384222 exceeds vegasRatioMax=0.2241491617964645, yy=160.92958898791784 program will now exit
# ratio=117.76878932122496 exceeds vegasRatioMax=0.2241491617964645, yy=444.71315860076066 program will now exit
# ratio=381.3009060202157 exceeds vegasRatioMax=0.2241491617964645, yy=679.738327120562 program will now exit
# ratio=0.2925214861827737 exceeds vegasRatioMax=0.2241491617964645, yy=21.709746731337788 program will now exit
# ratio=61.18854489582182 exceeds vegasRatioMax=0.2241491617964645, yy=439.5972569077826 program will now exit
# ratio=0.5046557313042372 exceeds vegasRatioMax=0.2241491617964645, yy=43.58010999620988 program will now exit
# ratio=9.33921133899188 exceeds vegasRatioMax=0.2241491617964645, yy=148.23555906132037 program will now exit
# ratio=845.0204707092141 exceeds vegasRatioMax=0.2241491617964645, yy=1514.420198319355 program will now exit
# ratio=15.149765582713755 exceeds vegasRatioMax=0.2241491617964645, yy=153.44260405799082 program will now exit
# ratio=0.5994638163352138 exceeds vegasRatioMax=0.2241491617964645, yy=36.86778983245786 program will now exit
# ratio=1.322829971617267 exceeds vegasRatioMax=0.2241491617964645, yy=47.50805742073784 program will now exit
# ratio=810.6973491198163 exceeds vegasRatioMax=0.2241491617964645, yy=1354.2868554641066 program will now exit
# ratio=18.941123156197055 exceeds vegasRatioMax=0.2241491617964645, yy=237.61659937888788 program will now exit
# ratio=110829.28972466118 exceeds vegasRatioMax=0.2241491617964645, yy=13787.495949857777 program will now exit
# ratio=0.3656872829547623 exceeds vegasRatioMax=0.2241491617964645, yy=23.57354778958642 program will now exit
# ratio=0.35079780636496605 exceeds vegasRatioMax=0.2241491617964645, yy=34.43579682431462 program will now exit
# ratio=1.439723715359213 exceeds vegasRatioMax=0.2241491617964645, yy=66.6500040448709 program will now exit
# ratio=62826.29112089041 exceeds vegasRatioMax=0.2241491617964645, yy=14129.232072614992 program will now exit
# ratio=8.446500707972731 exceeds vegasRatioMax=0.2241491617964645, yy=143.4821159386013 program will now exit
# ratio=0.8676014300621556 exceeds vegasRatioMax=0.2241491617964645, yy=32.819686166457494 program will now exit
# ratio=0.8246061176106159 exceeds vegasRatioMax=0.2241491617964645, yy=27.293289753789857 program will now exit
# ratio=13.811868716761337 exceeds vegasRatioMax=0.2241491617964645, yy=188.7041223462519 program will now exit
# ratio=1.4403275546788488 exceeds vegasRatioMax=0.2241491617964645, yy=40.27166393167047 program will now exit
# ratio=0.9336626094477338 exceeds vegasRatioMax=0.2241491617964645, yy=32.6243255220342 program will now exit
# ratio=13.534773231562161 exceeds vegasRatioMax=0.2241491617964645, yy=201.37121953116815 program will now exit
# ratio=268.87410229337115 exceeds vegasRatioMax=0.2241491617964645, yy=777.8797184459819 program will now exit
# ratio=68933.09214557942 exceeds vegasRatioMax=0.2241491617964645, yy=9137.941961300729 program will now exit
# ratio=9.668933690839745 exceeds vegasRatioMax=0.2241491617964645, yy=164.97204572663307 program will now exit
# ratio=32.17281300906694 exceeds vegasRatioMax=0.2241491617964645, yy=224.10353983115132 program will now exit
# ratio=0.8468770795021181 exceeds vegasRatioMax=0.2241491617964645, yy=50.278154217533526 program will now exit
# ratio=0.3534508022841514 exceeds vegasRatioMax=0.2241491617964645, yy=20.203025657580046 program will now exit
# ratio=2043.4819189995383 exceeds vegasRatioMax=0.2241491617964645, yy=2214.066701868534 program will now exit
# ratio=0.2695387659932475 exceeds vegasRatioMax=0.2241491617964645, yy=24.326742107611945 program will now exit
# ratio=0.5470468382003163 exceeds vegasRatioMax=0.2241491617964645, yy=29.470116227977165 program will now exit
# ratio=2433.273461383184 exceeds vegasRatioMax=0.2241491617964645, yy=2044.0933817450887 program will now exit
# ratio=117.42968443136148 exceeds vegasRatioMax=0.2241491617964645, yy=474.37343789656927 program will now exit
# ratio=3.9271364585317055 exceeds vegasRatioMax=0.2241491617964645, yy=104.10138335181769 program will now exit
# ratio=65.69210955441854 exceeds vegasRatioMax=0.2241491617964645, yy=413.8286249421426 program will now exit
# ratio=0.6144167441490861 exceeds vegasRatioMax=0.2241491617964645, yy=24.714291476073047 program will now exit
# ratio=247.3493947243383 exceeds vegasRatioMax=0.2241491617964645, yy=719.791208812235 program will now exit
# ratio=12.505720429525757 exceeds vegasRatioMax=0.2241491617964645, yy=173.31767148386976 program will now exit
# ratio=0.40320061687737146 exceeds vegasRatioMax=0.2241491617964645, yy=27.384255665767817 program will now exit
# ratio=1.3521525320540413 exceeds vegasRatioMax=0.2241491617964645, yy=47.679084201032865 program will now exit
# ratio=0.2809352388617182 exceeds vegasRatioMax=0.2241491617964645, yy=26.3795948050269 program will now exit
# ratio=0.6404735970512215 exceeds vegasRatioMax=0.2241491617964645, yy=34.85050448407449 program will now exit
# ratio=0.24349989251902057 exceeds vegasRatioMax=0.2241491617964645, yy=16.979810431714736 program will now exit
# ratio=0.30998683319143866 exceeds vegasRatioMax=0.2241491617964645, yy=20.786149689939222 program will now exit
# ratio=115.14468460668321 exceeds vegasRatioMax=0.2241491617964645, yy=537.0049087053665 program will now exit
# ratio=207.65062615938973 exceeds vegasRatioMax=0.2241491617964645, yy=694.7016840974359 program will now exit
# ratio=1.227252080242991 exceeds vegasRatioMax=0.2241491617964645, yy=29.181492428889747 program will now exit
# ratio=0.40003169146647743 exceeds vegasRatioMax=0.2241491617964645, yy=32.26966030729671 program will now exit
# ratio=155.34522458695463 exceeds vegasRatioMax=0.2241491617964645, yy=619.5740007181756 program will now exit
# ratio=2.4010370449950713 exceeds vegasRatioMax=0.2241491617964645, yy=112.67113645078884 program will now exit
# ratio=362.167197337125 exceeds vegasRatioMax=0.2241491617964645, yy=910.1741078843652 program will now exit
# ratio=134.49728711744737 exceeds vegasRatioMax=0.2241491617964645, yy=585.3438089806853 program will now exit
# ratio=0.36292131219448526 exceeds vegasRatioMax=0.2241491617964645, yy=15.73459291778978 program will now exit
# ratio=6.2536996580946465 exceeds vegasRatioMax=0.2241491617964645, yy=102.23494155725348 program will now exit
# ratio=0.6033362909239203 exceeds vegasRatioMax=0.2241491617964645, yy=27.481817542816316 program will now exit
# 13468
# 0.2241491617964645
# 193600.87941939358

# %%
lego_plot(np.sqrt(s_vegas), cos_vegas, 100, "E", "Cos", "New Method")
plot_histograms(s_vegas, cos_vegas, 100)

# %%
import time
n_events = 10000
start_time_ar = time.time()
s_rej_method, cos_theta_rej_method, nFunctionEval_rej, maxWeightEncounteredReJ= brute_force(n_events)
end_time_ar = time.time()
time_ar = end_time_ar - start_time_ar

start_time_vegas = time.time()
s_vegas, cos_vegas, nFunctionalEval_vegas, maxweightEncounteredvegas,vegasRatioFactor = vegas(n_events,0.1,100,2000,4000,1.5)
end_time_vegas = time.time()
time_vegas = end_time_vegas - start_time_vegas

print("Acceptance-Rejection Method:")
print(f"Number of function evaluations: {nFunctionEval_rej}")
print(f"Time taken: {time_ar} seconds")

print("\nVEGAS Method:")
print(f"Time taken: {time_vegas} seconds")
print(f"Number of function evaluations: {nFunctionalEval_vegas}")
# Out:
# C:\Users\Nedal\AppData\Local\Temp\ipykernel_22488\1050001430.py:43: RuntimeWarning: invalid value encountered in log
#   mmx = KK * pow((logArgx - 1) / np.log(logArgx), alpha_damp)
# C:\Users\Nedal\AppData\Local\Temp\ipykernel_22488\1050001430.py:44: RuntimeWarning: invalid value encountered in cast
#   mmx = mmx.astype(int)
# Acceptance-Rejection Method:
# Number of function evaluations: 645880
# Time taken: 14.47813606262207 seconds
#
# VEGAS Method:
# Time taken: 31.57294487953186 seconds
# Number of function evaluations: 431915

# %%
events = [1000,10000,50000,100000,300000]
ar_times = []
vegas_times = []
for i in enumerate(events):
    start_time_ar = time.time()
    s_rej_method, cos_theta_rej_method, nFunctionEval_rej, maxWeightEncounteredReJ= brute_force(n_events)
    end_time_ar = time.time()
    time_ar = end_time_ar - start_time_ar
    ar_times.append(time_ar)

    start_time_vegas = time.time()
    s_vegas, cos_vegas, nFunctionalEval_vegas, maxweightEncounteredvegas,vegasRatioFactor = vegas(n_events,0.1,100,2000,4000,1.5)
    end_time_vegas = time.time()
    time_vegas = end_time_vegas - start_time_vegas
    vegas_times.append(time_vegas)
plt.plot(events,vegas_times)
plt.plot(events,ar_times)
plt.legend()
plt.show()
# Out:
# C:\Users\Nedal\AppData\Local\Temp\ipykernel_22488\1050001430.py:43: RuntimeWarning: invalid value encountered in log
#   mmx = KK * pow((logArgx - 1) / np.log(logArgx), alpha_damp)
# C:\Users\Nedal\AppData\Local\Temp\ipykernel_22488\1050001430.py:44: RuntimeWarning: invalid value encountered in cast
#   mmx = mmx.astype(int)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# Out:
# 10
# 100
# 1000
# 10000
# 100000
# 300000
# 700000
# 1000000
